# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

pd.pandas.set_option('display.max_columns',None)
#To display max no of columnns without '...'

# %%
df_test = pd.read_csv(r'F:\Ineuron\EDA\House prediction\test.csv')

# %%
df_train = pd.read_csv(r'F:\Ineuron\EDA\House prediction\train.csv')

# %%
df_train.shape
#print shape of dataset
# Out:
# (1460, 81)

# %%
df_train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
#1. Missing values

# %%
df_train.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
features = df_train.columns

# %%
feature_with_na = []
for i in features:
    if df_train[i].isnull().sum() >=1:
        feature_with_na.append(i)

# %%
feature_with_na
#saving all features that has nan values in this variable
# Out:
# ['LotFrontage',
#  'Alley',
#  'MasVnrType',
#  'MasVnrArea',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Electrical',
#  'FireplaceQu',
#  'GarageType',
#  'GarageYrBlt',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PoolQC',
#  'Fence',
#  'MiscFeature']

# %%
for feature in feature_with_na:
    print(feature,np.round(df_train[feature].isnull().mean()*100, 4) ,'% missing value')
# Out:
# LotFrontage 17.7397 % missing value
# Alley 93.7671 % missing value
# MasVnrType 0.5479 % missing value
# MasVnrArea 0.5479 % missing value
# BsmtQual 2.5342 % missing value
# BsmtCond 2.5342 % missing value
# BsmtExposure 2.6027 % missing value
# BsmtFinType1 2.5342 % missing value
# BsmtFinType2 2.6027 % missing value
# Electrical 0.0685 % missing value
# FireplaceQu 47.2603 % missing value
# GarageType 5.5479 % missing value
# GarageYrBlt 5.5479 % missing value
# GarageFinish 5.5479 % missing value
# GarageQual 5.5479 % missing value
# GarageCond 5.5479 % missing value
# PoolQC 99.5205 % missing value
# Fence 80.7534 % missing value
# MiscFeature 96.3014 % missing value

# %%
data = df_train.copy()
for feature in feature_with_na:
    data[feature] = np.where(data[feature].isnull(),1,0)
    k = data.groupby(feature)['SalePrice'].median().plot.bar()
    plt.title(feature)
    plt.show()

# %%
#2. Numerical varibales

# %%
df_train['SalePrice']
# Out:
# 0       208500
# 1       181500
# 2       223500
# 3       140000
# 4       250000
#          ...
# 1455    175000
# 1456    210000
# 1457    266500
# 1458    142125
# 1459    147500
# Name: SalePrice, Length: 1460, dtype: int64

# %%
Numerical_fea = []
for i in df_train.columns:
    if df_train[i].dtype != 'object':
        Numerical_fea.append(i)

# %%
Numerical_fea
# Out:
# ['Id',
#  'MSSubClass',
#  'LotFrontage',
#  'LotArea',
#  'OverallQual',
#  'OverallCond',
#  'YearBuilt',
#  'YearRemodAdd',
#  'MasVnrArea',
#  'BsmtFinSF1',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'LowQualFinSF',
#  'GrLivArea',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'FullBath',
#  'HalfBath',
#  'BedroomAbvGr',
#  'KitchenAbvGr',
#  'TotRmsAbvGrd',
#  'Fireplaces',
#  'GarageYrBlt',
#  'GarageCars',
#  'GarageArea',
#  'WoodDeckSF',
#  'OpenPorchSF',
#  'EnclosedPorch',
#  '3SsnPorch',
#  'ScreenPorch',
#  'PoolArea',
#  'MiscVal',
#  'MoSold',
#  'YrSold',
#  'SalePrice']

# %%
#3. Temporal variables [day time variables]

# %%
Year_fea = []
for j in Numerical_fea:
    if 'Yr' in j or 'Year' in j:
        Year_fea.append(j)

# %%
Year_fea
# Out:
# ['YearBuilt', 'YearRemodAdd', 'GarageYrBlt', 'YrSold']

# %%
for j in Year_fea:
    print(j,df_train[j].unique())
# Out:
# YearBuilt [2003 1976 2001 1915 2000 1993 2004 1973 1931 1939 1965 2005 1962 2006
#  1960 1929 1970 1967 1958 1930 2002 1968 2007 1951 1957 1927 1920 1966
#  1959 1994 1954 1953 1955 1983 1975 1997 1934 1963 1981 1964 1999 1972
#  1921 1945 1982 1998 1956 1948 1910 1995 1991 2009 1950 1961 1977 1985
#  1979 1885 1919 1990 1969 1935 1988 1971 1952 1936 1923 1924 1984 1926
#  1940 1941 1987 1986 2008 1908 1892 1916 1932 1918 1912 1947 1925 1900
#  1980 1989 1992 1949 1880 1928 1978 1922 1996 2010 1946 1913 1937 1942
#  1938 1974 1893 1914 1906 1890 1898 1904 1882 1875 1911 1917 1872 1905]
# YearRemodAdd [2003 1976 2002 1970 2000 1995 2005 1973 1950 1965 2006 1962 2007 1960
#  2001 1967 2004 2008 1997 1959 1990 1955 1983 1980 1966 1963 1987 1964
#  1972 1996 1998 1989 1953 1956 1968 1981 1992 2009 1982 1961 1993 1999
#  1985 1979 1977 1969 1958 1991 1971 1952 1975 2010 1984 1986 1994 1988
#  1954 1957 1951 1978 1974]
# ...

# %%
data = df_train.copy()
for i in Year_fea:
    if i!= 'YrSold':
        data[i] = data['YrSold'] -  data[i]
        plt.scatter(data[i],data['SalePrice'])
        plt.xlabel(i)
        plt.ylabel('SalePrice')
        plt.show()

# %%
#distribution is power law based as per our observation

# %%
discrete = []
for i in Numerical_fea:
    if len(df_train[i].unique())<=25:
        discrete.append(i)

# %%
data = df_train.copy()
for i in discrete:
    data.groupby(i)['SalePrice'].median().plot.bar()
    plt.show()

# %%
continous = []
for i in Numerical_fea :
    if i not in discrete+Year_fea:
        continous.append(i)

# %%
continous
# Out:
# ['Id',
#  'LotFrontage',
#  'LotArea',
#  'MasVnrArea',
#  'BsmtFinSF1',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'GrLivArea',
#  'GarageArea',
#  'WoodDeckSF',
#  'OpenPorchSF',
#  'EnclosedPorch',
#  'ScreenPorch',
#  'SalePrice']

# %%
data = df_train.copy()
for i in continous:
    if data[i] == 0:
        pass
    else:
    data.groupby(i)['SalePrice'].median().plot.hist()
    plt.show()
# Out:
#   File "<ipython-input-28-a735c9ab84b0>", line 6
#     data.groupby(i)['SalePrice'].median().plot.hist()
#     ^
# IndentationError: expected an indented block

# %%
data = df_train.copy()

for i in continous:
    data[i] = np.log(data[i])
    plt.scatter(data[i],data['SalePrice'])
    plt.show()
# Out:
# C:\Users\Administrator\anaconda3\lib\site-packages\pandas\core\arraylike.py:358: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
data = df_train.copy()

for i in continous:
    if 0 in data[i].unique():
        pass
    else:
        data[i] = np.log(data[i])
        data.boxplot(column = i)
        plt.show()

# %%
#categorical variables

# %%
Categorical_fea = []
for i in df_train.columns:
    if df_train[i].dtype == 'object':
        Categorical_fea.append(i)

# %%
Categorical_fea
# Out:
# ['MSZoning',
#  'Street',
#  'Alley',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'Electrical',
#  'KitchenQual',
#  'Functional',
#  'FireplaceQu',
#  'GarageType',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PavedDrive',
#  'PoolQC',
#  'Fence',
#  'MiscFeature',
#  'SaleType',
#  'SaleCondition']

# %%
data['SaleCondition']
# Out:
# 0        Normal
# 1        Normal
# 2        Normal
# 3       Abnorml
# 4        Normal
#          ...
# 1455     Normal
# 1456     Normal
# 1457     Normal
# 1458     Normal
# 1459     Normal
# Name: SaleCondition, Length: 1460, dtype: object

# %%
#Feture engineering

# %%
df_train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
x = df_train.iloc[:,1:80]
y = df_train[['SalePrice']]

# %%
x
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0             60       RL         65.0     8450   Pave   NaN      Reg
# 1             20       RL         80.0     9600   Pave   NaN      Reg
# 2             60       RL         68.0    11250   Pave   NaN      IR1
# 3             70       RL         60.0     9550   Pave   NaN      IR1
# 4             60       RL         84.0    14260   Pave   NaN      IR1
# ...          ...      ...          ...      ...    ...   ...      ...
# 1455          60       RL         62.0     7917   Pave   NaN      Reg
# 1456          20       RL         85.0    13175   Pave   NaN      Reg
# 1457          70       RL         66.0     9042   Pave   NaN      Reg
# 1458          20       RL         68.0     9717   Pave   NaN      Reg
# 1459          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# ...

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.1)

# %%
x_train
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1146          20       RL          NaN    11200   Pave   NaN      Reg
# 733           20       RL         80.0    10000   Pave   NaN      Reg
# 241           30       RM         40.0     3880   Pave   NaN      Reg
# 895           60       RL         71.0     7056   Pave   NaN      Reg
# 576           50       RL         52.0     6292   Pave   NaN      Reg
# ...          ...      ...          ...      ...    ...   ...      ...
# 1058          60       RL         96.0    11308   Pave   NaN      IR1
# 1420          60       RL         90.0    11700   Pave   NaN      Reg
# 798           60       RL        104.0    13518   Pave   NaN      Reg
# 1271          20       RL          NaN     9156   Pave   NaN      IR1
# 909           60       RL        149.0    12589   Pave   NaN      IR2
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# ...

# %%
x_test
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 885          120       FV         50.0     5119   Pave   NaN      IR1
# 1300          60       RL          NaN    10762   Pave   NaN      IR1
# 426           80       RL          NaN    12800   Pave   NaN      Reg
# 1429          20       RL          NaN    12546   Pave   NaN      IR1
# 486           20       RL         79.0    10289   Pave   NaN      Reg
# ...          ...      ...          ...      ...    ...   ...      ...
# 1022          50       RM         52.0     9439   Pave   NaN      Reg
# 458           70       RM          NaN     5100   Pave  Grvl      Reg
# 1280          20       RL         67.0     9808   Pave   NaN      IR1
# 1147          70       RL         75.0    12000   Pave   NaN      Reg
# 146           30       RM         51.0     6120   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# ...

# %%
y_train
# Out:
#       SalePrice
# 1146     180000
# 733      131400
# 241      110500
# 895      140000
# 576      145000
# ...         ...
# 1058     335000
# 1420     179900
# 798      485000
# 1271     185750
# 909      174000
#
# [1314 rows x 1 columns]

# %%
y_test
# Out:
#       SalePrice
# 885      328900
# 1300     225000
# 426      275000
# 1429     182900
# 486      156000
# ...         ...
# 1022      87000
# 458      161000
# 1280     227000
# 1147     174500
# 146      105000
#
# [146 rows x 1 columns]

# %%
#Missing values

# %%
feature_with_na
# Out:
# ['LotFrontage',
#  'Alley',
#  'MasVnrType',
#  'MasVnrArea',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Electrical',
#  'FireplaceQu',
#  'GarageType',
#  'GarageYrBlt',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PoolQC',
#  'Fence',
#  'MiscFeature']

# %%
for feature in feature_with_na:
    print(feature,np.round(df_train[feature].isnull().mean()*100, 4) ,'% missing value')
# Out:
# LotFrontage 17.7397 % missing value
# Alley 93.7671 % missing value
# MasVnrType 0.5479 % missing value
# MasVnrArea 0.5479 % missing value
# BsmtQual 2.5342 % missing value
# BsmtCond 2.5342 % missing value
# BsmtExposure 2.6027 % missing value
# BsmtFinType1 2.5342 % missing value
# BsmtFinType2 2.6027 % missing value
# Electrical 0.0685 % missing value
# FireplaceQu 47.2603 % missing value
# GarageType 5.5479 % missing value
# GarageYrBlt 5.5479 % missing value
# GarageFinish 5.5479 % missing value
# GarageQual 5.5479 % missing value
# GarageCond 5.5479 % missing value
# PoolQC 99.5205 % missing value
# Fence 80.7534 % missing value
# MiscFeature 96.3014 % missing value

# %%
Categorical_fea
# Out:
# ['MSZoning',
#  'Street',
#  'Alley',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'Electrical',
#  'KitchenQual',
#  'Functional',
#  'FireplaceQu',
#  'GarageType',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PavedDrive',
#  'PoolQC',
#  'Fence',
#  'MiscFeature',
#  'SaleType',
#  'SaleCondition']

# %%
#method1
data1 = df_train.copy()
def rep_cat(data1,Categorical_fea):
    data1[Categorical_fea] = data1[Categorical_fea].fillna('missing')

# %%
rep_cat(data1,Categorical_fea)

# %%
data1.head(250)
# Out:
#       Id  MSSubClass MSZoning  LotFrontage  LotArea Street    Alley LotShape  \
# 0      1          60       RL         65.0     8450   Pave  missing      Reg
# 1      2          20       RL         80.0     9600   Pave  missing      Reg
# 2      3          60       RL         68.0    11250   Pave  missing      IR1
# 3      4          70       RL         60.0     9550   Pave  missing      IR1
# 4      5          60       RL         84.0    14260   Pave  missing      IR1
# ..   ...         ...      ...          ...      ...    ...      ...      ...
# 245  246          20       RL         80.0    10400   Pave  missing      Reg
# 246  247         190       RM         69.0     9142   Pave     Grvl      Reg
# 247  248          20       RL         75.0    11310   Pave  missing      Reg
# 248  249          60       RL         72.0    11317   Pave  missing      Reg
# 249  250          50       RL          NaN   159000   Pave  missing      IR2
#
# ...

# %%
#method2
#if nan is higher than it is replaced with NAN so it is not useful here
import statistics as stat
data2 = df_train.copy()
def rep_cat(data2,Categorical_fea):
    for feature in Categorical_fea:
        data2[feature] = data2[feature].fillna(statistics.mode(feature))

# %%
data2.head(10)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
# 5   6          50       RL         85.0    14115   Pave   NaN      IR1
# 6   7          20       RL         75.0    10084   Pave   NaN      Reg
# 7   8          60       RL          NaN    10382   Pave   NaN      IR1
# 8   9          50       RM         51.0     6120   Pave   NaN      Reg
# 9  10         190       RL         50.0     7420   Pave   NaN      Reg
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# ...

# %%
Numerical_fea_with_nan = []
for i in df_train.columns:
    if df_train[i].dtype != 'object' and df_train[i].isnull().sum() >=1:
        Numerical_fea_with_nan.append(i)

# %%
Numerical_fea_with_nan
# Out:
# ['LotFrontage', 'MasVnrArea', 'GarageYrBlt']

# %%
for feature in Numerical_fea_with_nan:
    median_val = df_train[feature].median()
    df_train[feature + 'Nan'] = np.where(df_train[feature].isnull(),1,0)
    df_train[feature].fillna(median_val,inplace = True)

# %%
df_train
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
df_train.tail(100)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1360  1361          70       RL         51.0     9842   Pave   NaN      Reg
# 1361  1362          20       RL        124.0    16158   Pave   NaN      IR1
# 1362  1363          50       RL         69.0    12513   Pave   NaN      IR1
# 1363  1364          60       RL         73.0     8499   Pave   NaN      IR1
# 1364  1365         160       FV         30.0     3180   Pave  Pave      Reg
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
age_fea = Year_fea.copy()

# %%
age_fea
# Out:
# ['YearBuilt', 'YearRemodAdd', 'GarageYrBlt', 'YrSold']

# %%
age_fea.remove('YrSold')

# %%
for i in age_fea:
    df_train[i +'_'+ 'age'] = df_train['YrSold'] - df_train[i]

# %%
df_train.drop('YrSoldage',axis = 1)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
df_train.drop('YrSold_age',axis = 1)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...
